# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('combined_data__weather_twitter_flood.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0        time  weathercode (wmo code)  temperature_2m_max (°C)  \
# 0           0  2009-01-01                     2.0                     33.2
# 1           1  2009-01-02                    51.0                     32.3
# 2           2  2009-01-03                    51.0                     32.5
# 3           3  2009-01-04                     1.0                     33.4
# 4           4  2009-01-05                     2.0                     34.2
#
#    temperature_2m_min (°C)  temperature_2m_mean (°C)  \
# 0                     21.9                      27.2
# 1                     23.3                      27.1
# 2                     22.7                      27.1
# 3                     22.2                      27.5
# 4                     22.2                      27.8
#
#    apparent_temperature_max (°C)  apparent_temperature_min (°C)  \
# 0                           34.6                           25.7
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58707 entries, 0 to 58706
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       58707 non-null  int64
#  1   time                             58707 non-null  object
#  2   weathercode (wmo code)           58685 non-null  float64
#  3   temperature_2m_max (°C)          58685 non-null  float64
#  4   temperature_2m_min (°C)          58685 non-null  float64
#  5   temperature_2m_mean (°C)         58685 non-null  float64
#  6   apparent_temperature_max (°C)    58685 non-null  float64
#  7   apparent_temperature_min (°C)    58685 non-null  float64
#  8   apparent_temperature_mean (°C)   58685 non-null  float64
#  9   precipitation_sum (mm)           58685 non-null  float64
#  10  rain_sum (mm)                    58685 non-null  float64
# ...

# %%
df1.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58707 entries, 0 to 58706
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   time                             58707 non-null  object
#  1   weathercode (wmo code)           58685 non-null  float64
#  2   temperature_2m_max (°C)          58685 non-null  float64
#  3   temperature_2m_min (°C)          58685 non-null  float64
#  4   temperature_2m_mean (°C)         58685 non-null  float64
#  5   apparent_temperature_max (°C)    58685 non-null  float64
#  6   apparent_temperature_min (°C)    58685 non-null  float64
#  7   apparent_temperature_mean (°C)   58685 non-null  float64
#  8   precipitation_sum (mm)           58685 non-null  float64
#  9   rain_sum (mm)                    58685 non-null  float64
#  10  precipitation_hours (h)          58707 non-null  float64
# ...

# %%
df1.rename(columns = {'event_one_hot':'intensity_flood'}, inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58707 entries, 0 to 58706
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   time                             58707 non-null  object
#  1   weathercode (wmo code)           58685 non-null  float64
#  2   temperature_2m_max (°C)          58685 non-null  float64
#  3   temperature_2m_min (°C)          58685 non-null  float64
#  4   temperature_2m_mean (°C)         58685 non-null  float64
#  5   apparent_temperature_max (°C)    58685 non-null  float64
#  6   apparent_temperature_min (°C)    58685 non-null  float64
#  7   apparent_temperature_mean (°C)   58685 non-null  float64
#  8   precipitation_sum (mm)           58685 non-null  float64
#  9   rain_sum (mm)                    58685 non-null  float64
#  10  precipitation_hours (h)          58707 non-null  float64
# ...

# %%
df1.head()
# Out:
#          time  weathercode (wmo code)  temperature_2m_max (°C)  \
# 0  2009-01-01                     2.0                     33.2
# 1  2009-01-02                    51.0                     32.3
# 2  2009-01-03                    51.0                     32.5
# 3  2009-01-04                     1.0                     33.4
# 4  2009-01-05                     2.0                     34.2
#
#    temperature_2m_min (°C)  temperature_2m_mean (°C)  \
# 0                     21.9                      27.2
# 1                     23.3                      27.1
# 2                     22.7                      27.1
# 3                     22.2                      27.5
# 4                     22.2                      27.8
#
#    apparent_temperature_max (°C)  apparent_temperature_min (°C)  \
# 0                           34.6                           25.7
# 1                           33.9                           28.2
# 2                           35.0                           27.1
# ...

# %%
df1['date_time'] = pd.to_datetime(df1['time'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58707 entries, 0 to 58706
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   time                             58707 non-null  object
#  1   weathercode (wmo code)           58685 non-null  float64
#  2   temperature_2m_max (°C)          58685 non-null  float64
#  3   temperature_2m_min (°C)          58685 non-null  float64
#  4   temperature_2m_mean (°C)         58685 non-null  float64
#  5   apparent_temperature_max (°C)    58685 non-null  float64
#  6   apparent_temperature_min (°C)    58685 non-null  float64
#  7   apparent_temperature_mean (°C)   58685 non-null  float64
#  8   precipitation_sum (mm)           58685 non-null  float64
#  9   rain_sum (mm)                    58685 non-null  float64
#  10  precipitation_hours (h)          58707 non-null  float64
# ...

# %%
drop_columns=['time','Year','Month','Day','event_type','event_intensity']
df1.drop(drop_columns,axis=1,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58707 entries, 0 to 58706
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   weathercode (wmo code)           58685 non-null  float64
#  1   temperature_2m_max (°C)          58685 non-null  float64
#  2   temperature_2m_min (°C)          58685 non-null  float64
#  3   temperature_2m_mean (°C)         58685 non-null  float64
#  4   apparent_temperature_max (°C)    58685 non-null  float64
#  5   apparent_temperature_min (°C)    58685 non-null  float64
#  6   apparent_temperature_mean (°C)   58685 non-null  float64
#  7   precipitation_sum (mm)           58685 non-null  float64
#  8   rain_sum (mm)                    58685 non-null  float64
#  9   precipitation_hours (h)          58707 non-null  float64
#  10  windspeed_10m_max (km/h)         58685 non-null  float64
# ...

# %%
df1.head()
# Out:
#    weathercode (wmo code)  temperature_2m_max (°C)  temperature_2m_min (°C)  \
# 0                     2.0                     33.2                     21.9
# 1                    51.0                     32.3                     23.3
# 2                    51.0                     32.5                     22.7
# 3                     1.0                     33.4                     22.2
# 4                     2.0                     34.2                     22.2
#
#    temperature_2m_mean (°C)  apparent_temperature_max (°C)  \
# 0                      27.2                           34.6
# 1                      27.1                           33.9
# 2                      27.1                           35.0
# 3                      27.5                           35.0
# 4                      27.8                           36.1
#
#    apparent_temperature_min (°C)  apparent_temperature_mean (°C)  \
# 0                           25.7                            29.8
# ...

# %%
df1.to_csv('flood.csv',index=False)
