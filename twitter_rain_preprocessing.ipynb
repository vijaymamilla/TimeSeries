# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('combined_data__weather_twitter_rain.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        time  weathercode (wmo code)  temperature_2m_max (°C)  \
# 0           0  2009-01-01                     2.0                     33.2
# 1           1  2009-01-02                    51.0                     32.3
# 2           2  2009-01-03                    51.0                     32.5
# 3           3  2009-01-04                     1.0                     33.4
# 4           4  2009-01-05                     2.0                     34.2
#
#    temperature_2m_min (°C)  temperature_2m_mean (°C)  \
# 0                     21.9                      27.2
# 1                     23.3                      27.1
# 2                     22.7                      27.1
# 3                     22.2                      27.5
# 4                     22.2                      27.8
#
#    apparent_temperature_max (°C)  apparent_temperature_min (°C)  \
# 0                           34.6                           25.7
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0  weathercode (wmo code)  temperature_2m_max (°C)  \
# count  58707.000000            58685.000000             58685.000000
# mean   29353.000000               38.172054                31.979259
# std    16947.395464               27.020412                 3.321538
# min        0.000000                0.000000                20.800000
# 25%    14676.500000                2.000000                29.500000
# 50%    29353.000000               51.000000                31.800000
# 75%    44029.500000               61.000000                34.400000
# max    58706.000000               65.000000                42.000000
#
#        temperature_2m_min (°C)  temperature_2m_mean (°C)  \
# count             58685.000000              58685.000000
# mean                 22.790584                 26.820917
# std                   2.070472                  2.174481
# min                  14.400000                 20.100000
# ...

# %%
df.shape
# Out:
# (58707, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58707 entries, 0 to 58706
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       58707 non-null  int64
#  1   time                             58707 non-null  object
#  2   weathercode (wmo code)           58685 non-null  float64
#  3   temperature_2m_max (°C)          58685 non-null  float64
#  4   temperature_2m_min (°C)          58685 non-null  float64
#  5   temperature_2m_mean (°C)         58685 non-null  float64
#  6   apparent_temperature_max (°C)    58685 non-null  float64
#  7   apparent_temperature_min (°C)    58685 non-null  float64
#  8   apparent_temperature_mean (°C)   58685 non-null  float64
#  9   precipitation_sum (mm)           58685 non-null  float64
#  10  rain_sum (mm)                    58685 non-null  float64
# ...

# %%
df['city']
# Out:
# 0        Atakpame
# 1        Atakpame
# 2        Atakpame
# 3        Atakpame
# 4        Atakpame
#            ...
# 58702       Mango
# 58703       Mango
# 58704       Mango
# 58705       Mango
# 58706       Mango
# Name: city, Length: 58707, dtype: object

# %%
df['city'].unique()
# Out:
# array(['Atakpame', 'Kara', 'Dapaong', 'Sokode', 'Bafilo', 'Kpalime',
#        'Bassar', 'Tsevie', 'Lome', 'Badou', 'Mango'], dtype=object)

# %%
df2 = df.loc[df['city'] == 'Atakpame']

# %%
df2.head()
# Out:
#    Unnamed: 0        time  weathercode (wmo code)  temperature_2m_max (°C)  \
# 0           0  2009-01-01                     2.0                     33.2
# 1           1  2009-01-02                    51.0                     32.3
# 2           2  2009-01-03                    51.0                     32.5
# 3           3  2009-01-04                     1.0                     33.4
# 4           4  2009-01-05                     2.0                     34.2
#
#    temperature_2m_min (°C)  temperature_2m_mean (°C)  \
# 0                     21.9                      27.2
# 1                     23.3                      27.1
# 2                     22.7                      27.1
# 3                     22.2                      27.5
# 4                     22.2                      27.8
#
#    apparent_temperature_max (°C)  apparent_temperature_min (°C)  \
# 0                           34.6                           25.7
# ...

# %%
df2.shape
# Out:
# (5337, 27)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5337 entries, 0 to 5336
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       5337 non-null   int64
#  1   time                             5337 non-null   object
#  2   weathercode (wmo code)           5335 non-null   float64
#  3   temperature_2m_max (°C)          5335 non-null   float64
#  4   temperature_2m_min (°C)          5335 non-null   float64
#  5   temperature_2m_mean (°C)         5335 non-null   float64
#  6   apparent_temperature_max (°C)    5335 non-null   float64
#  7   apparent_temperature_min (°C)    5335 non-null   float64
#  8   apparent_temperature_mean (°C)   5335 non-null   float64
#  9   precipitation_sum (mm)           5335 non-null   float64
#  10  rain_sum (mm)                    5335 non-null   float64
# ...

# %%
df2['date_time'] = pd.to_datetime(df2['time'])
# Out:
# /var/folders/1d/w72pys2d2q58j17kf_kg6h300000gr/T/ipykernel_13282/1206361973.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['date_time'] = pd.to_datetime(df2['time'])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5337 entries, 0 to 5336
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       5337 non-null   int64
#  1   time                             5337 non-null   object
#  2   weathercode (wmo code)           5335 non-null   float64
#  3   temperature_2m_max (°C)          5335 non-null   float64
#  4   temperature_2m_min (°C)          5335 non-null   float64
#  5   temperature_2m_mean (°C)         5335 non-null   float64
#  6   apparent_temperature_max (°C)    5335 non-null   float64
#  7   apparent_temperature_min (°C)    5335 non-null   float64
#  8   apparent_temperature_mean (°C)   5335 non-null   float64
#  9   precipitation_sum (mm)           5335 non-null   float64
#  10  rain_sum (mm)                    5335 non-null   float64
# ...

# %%
df2 = df2.drop_duplicates(subset='date_time',ignore_index=True)

# %%
df2.shape
# Out:
# (5337, 28)

# %%
print(df2['date_time'].min())
print(df2['date_time'].max())
# Out:
# 2009-01-01 00:00:00
# 2023-08-12 00:00:00

# %%
df2.isna().sum()
# Out:
# Unnamed: 0                         0
# time                               0
# weathercode (wmo code)             2
# temperature_2m_max (°C)            2
# temperature_2m_min (°C)            2
# temperature_2m_mean (°C)           2
# apparent_temperature_max (°C)      2
# apparent_temperature_min (°C)      2
# apparent_temperature_mean (°C)     2
# precipitation_sum (mm)             2
# rain_sum (mm)                      2
# precipitation_hours (h)            0
# windspeed_10m_max (km/h)           2
# windgusts_10m_max (km/h)           2
# winddirection_10m_dominant (°)     2
# et0_fao_evapotranspiration (mm)    2
# latitude                           0
# longitude                          0
# elevation                          0
# river_discharge                    0
# city                               0
# Year                               0
# Month                              0
# Day                                0
# event_type                         0
# ...

# %%
fig, ax = plt.subplots(figsize=(13,6))

ax.plot(df2.rain_sum)
ax.set_xlabel('Date')
ax.set_ylabel('Rain')

fig.autofmt_xdate()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1d/w72pys2d2q58j17kf_kg6h300000gr/T/ipykernel_13282/1317098256.py in <module>
# ----> 1 fig, ax = plt.subplots(figsize=(13,6))
#       2
#       3 ax.plot(df2.rain_sum)
#       4 ax.set_xlabel('Date')
#       5 ax.set_ylabel('Rain')
#
# NameError: name 'plt' is not defined
